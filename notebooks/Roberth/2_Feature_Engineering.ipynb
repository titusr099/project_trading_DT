# %%
import pandas as pd

# %%
# Cargar datos
csv_path = "../../data/processed/btc_silver.csv"
btc = pd.read_csv(csv_path)

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1561 entries, 0 to 1560
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1561 non-null   object
#  1   Close         1561 non-null   float64
#  2   High          1561 non-null   float64
#  3   Low           1561 non-null   float64
#  4   Open          1561 non-null   float64
#  5   Volume        1561 non-null   int64
#  6   daily_return  1561 non-null   float64
#  7   day_of_week   1561 non-null   int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 97.7+ KB

# %%
btc['Date'] = pd.to_datetime(btc['Date'])

# %%
btc.set_index('Date', inplace=True)

# %%
btc
# Out:
#                    Close          High           Low          Open  \
# Date
# 2020-12-25  24664.791016  24710.101562  23463.673828  23733.570312
# 2020-12-26  26437.037109  26718.070312  24522.689453  24677.015625
# 2020-12-27  26272.294922  28288.839844  25922.769531  26439.373047
# 2020-12-28  27084.808594  27389.111328  26207.640625  26280.822266
# 2020-12-29  27362.437500  27370.720703  25987.298828  27081.810547
# ...                  ...           ...           ...           ...
# 2025-04-07  79235.335938  81119.062500  74436.679688  78221.335938
# 2025-04-08  76271.953125  80823.890625  76198.023438  79218.476562
# 2025-04-09  82573.953125  83541.000000  74589.671875  76273.562500
# 2025-04-10  79626.140625  82700.929688  78456.132812  82565.976562
# 2025-04-11  82270.703125  83216.523438  78969.890625  79553.265625
#
#                  Volume  daily_return  day_of_week
# Date
# 2020-12-25  42068395846      0.039132            4
# 2020-12-26  48332647295      0.071853            5
# 2020-12-27  66479895605     -0.006231            6
# 2020-12-28  49056742893      0.030927            0
# 2020-12-29  45265946774      0.010250            1
# ...                 ...           ...          ...
# 2025-04-07  91262424987      0.013052            0
# 2025-04-08  48314590749     -0.037400            1
# 2025-04-09  84213627038      0.082625            2
# 2025-04-10  44718000633     -0.035699            3
# 2025-04-11  42343092224      0.033212            4
#
# [1561 rows x 7 columns]

# %%
import numpy as np
import ta

# %%
btc = btc.sort_index()

# %%
# Indicadores técnicos
btc['RSI_5'] = ta.momentum.RSIIndicator(close=btc['Close'], window=5).rsi()
macd = ta.trend.MACD(close=btc['Close'])
btc['MACD'] = macd.macd()
btc['MACD_signal'] = macd.macd_signal()
boll = ta.volatility.BollingerBands(close=btc['Close'])
btc['Bollinger_High'] = boll.bollinger_hband()
btc['Bollinger_Low'] = boll.bollinger_lband()

# %%
btc
# Out:
#                    Close          High           Low          Open  \
# Date
# 2020-12-25  24664.791016  24710.101562  23463.673828  23733.570312
# 2020-12-26  26437.037109  26718.070312  24522.689453  24677.015625
# 2020-12-27  26272.294922  28288.839844  25922.769531  26439.373047
# 2020-12-28  27084.808594  27389.111328  26207.640625  26280.822266
# 2020-12-29  27362.437500  27370.720703  25987.298828  27081.810547
# ...                  ...           ...           ...           ...
# 2025-04-07  79235.335938  81119.062500  74436.679688  78221.335938
# 2025-04-08  76271.953125  80823.890625  76198.023438  79218.476562
# 2025-04-09  82573.953125  83541.000000  74589.671875  76273.562500
# 2025-04-10  79626.140625  82700.929688  78456.132812  82565.976562
# 2025-04-11  82270.703125  83216.523438  78969.890625  79553.265625
#
#                  Volume  daily_return  day_of_week      RSI_5         MACD  \
# Date
# 2020-12-25  42068395846      0.039132            4        NaN          NaN
# 2020-12-26  48332647295      0.071853            5        NaN          NaN
# 2020-12-27  66479895605     -0.006231            6        NaN          NaN
# 2020-12-28  49056742893      0.030927            0        NaN          NaN
# 2020-12-29  45265946774      0.010250            1  94.566508          NaN
# ...                 ...           ...          ...        ...          ...
# 2025-04-07  91262424987      0.013052            0  30.459576 -1557.738511
# 2025-04-08  48314590749     -0.037400            1  21.384505 -1935.892233
# 2025-04-09  84213627038      0.082625            2  56.129819 -1707.381420
# 2025-04-10  44718000633     -0.035699            3  44.603545 -1744.044528
# 2025-04-11  42343092224      0.033212            4  54.972542 -1541.931782
#
#             MACD_signal  Bollinger_High  Bollinger_Low
# Date
# 2020-12-25          NaN             NaN            NaN
# 2020-12-26          NaN             NaN            NaN
# 2020-12-27          NaN             NaN            NaN
# 2020-12-28          NaN             NaN            NaN
# 2020-12-29          NaN             NaN            NaN
# ...                 ...             ...            ...
# 2025-04-07 -1204.760688    89029.606876   79109.436093
# 2025-04-08 -1350.986997    89379.251873   77701.563752
# 2025-04-09 -1422.265881    89306.680203   77614.811203
# 2025-04-10 -1486.621611    89310.543070   77169.238180
# 2025-04-11 -1497.683645    89240.128710   77083.474415
#
# [1561 rows x 12 columns]

# %%
btc.drop("daily_return", axis=1, inplace=True)
btc.drop("High", axis=1, inplace=True)
btc.drop("Low", axis=1, inplace=True)

# %%
btc
# Out:
#                    Close          Open       Volume  day_of_week      RSI_5  \
# Date
# 2020-12-25  24664.791016  23733.570312  42068395846            4        NaN
# 2020-12-26  26437.037109  24677.015625  48332647295            5        NaN
# 2020-12-27  26272.294922  26439.373047  66479895605            6        NaN
# 2020-12-28  27084.808594  26280.822266  49056742893            0        NaN
# 2020-12-29  27362.437500  27081.810547  45265946774            1  94.566508
# ...                  ...           ...          ...          ...        ...
# 2025-04-07  79235.335938  78221.335938  91262424987            0  30.459576
# 2025-04-08  76271.953125  79218.476562  48314590749            1  21.384505
# 2025-04-09  82573.953125  76273.562500  84213627038            2  56.129819
# 2025-04-10  79626.140625  82565.976562  44718000633            3  44.603545
# 2025-04-11  82270.703125  79553.265625  42343092224            4  54.972542
#
#                    MACD  MACD_signal  Bollinger_High  Bollinger_Low
# Date
# 2020-12-25          NaN          NaN             NaN            NaN
# 2020-12-26          NaN          NaN             NaN            NaN
# 2020-12-27          NaN          NaN             NaN            NaN
# 2020-12-28          NaN          NaN             NaN            NaN
# 2020-12-29          NaN          NaN             NaN            NaN
# ...                 ...          ...             ...            ...
# 2025-04-07 -1557.738511 -1204.760688    89029.606876   79109.436093
# 2025-04-08 -1935.892233 -1350.986997    89379.251873   77701.563752
# 2025-04-09 -1707.381420 -1422.265881    89306.680203   77614.811203
# 2025-04-10 -1744.044528 -1486.621611    89310.543070   77169.238180
# 2025-04-11 -1541.931782 -1497.683645    89240.128710   77083.474415
#
# [1561 rows x 9 columns]

# %%
# Precios anteriores
btc['Close_lag1'] = btc['Close'].shift(1)
btc['Open_lag1'] = btc['Open'].shift(1)
btc['Close_lag2'] = btc['Close'].shift(2)

# %%
# Indicadores anteriores
btc['RSI_5_lag1'] = btc['RSI_5'].shift(1)
btc['MACD_lag1'] = btc['MACD'].shift(1)

# %%
# Retornos y diferencias
btc['daily_return'] = btc['Close'].pct_change()
btc['daily_return_lag1'] = btc['daily_return'].shift(1)
btc['daily_return_lag2'] = btc['daily_return'].shift(2)
btc['diff_pct'] = (btc['Close'] - btc['Open']) / btc['Open']
btc['diff_pct_lag1'] = btc['diff_pct'].shift(1)

# %%
# Medias móviles
btc['rolling_mean_5'] = btc['Close'].rolling(window=5).mean()
btc['rolling_mean_10'] = btc['Close'].rolling(window=10).mean()
btc['mean_20'] = btc['Close'].rolling(window=20).mean()

# %%
# Desviación estándar (volatilidad)
btc['rolling_std_5'] = btc['Close'].rolling(window=5).std()
btc['std_10'] = btc['Close'].rolling(window=10).std()

# %%
# Variables temporales
btc['day_of_week'] = btc.index.dayofweek
btc['is_month_end'] = btc.index.is_month_end.astype(int)
btc['is_friday'] = (btc.index.dayofweek == 4).astype(int)

# %%
# Volumen
btc['volume_change'] = btc['Volume'].pct_change()
btc['volume_rolling_mean_5'] = btc['Volume'].rolling(window=5).mean()
btc['volume_rolling_std_5'] = btc['Volume'].rolling(window=5).std()

# %%
# Target (predicción de subida al día siguiente)
btc['target'] = (btc['Close'].shift(-1) > btc['Close']).astype(int)

# %%
btc
# Out:
#                    Close          Open       Volume  day_of_week      RSI_5  \
# Date
# 2020-12-25  24664.791016  23733.570312  42068395846            4        NaN
# 2020-12-26  26437.037109  24677.015625  48332647295            5        NaN
# 2020-12-27  26272.294922  26439.373047  66479895605            6        NaN
# 2020-12-28  27084.808594  26280.822266  49056742893            0        NaN
# 2020-12-29  27362.437500  27081.810547  45265946774            1  94.566508
# ...                  ...           ...          ...          ...        ...
# 2025-04-07  79235.335938  78221.335938  91262424987            0  30.459576
# 2025-04-08  76271.953125  79218.476562  48314590749            1  21.384505
# 2025-04-09  82573.953125  76273.562500  84213627038            2  56.129819
# 2025-04-10  79626.140625  82565.976562  44718000633            3  44.603545
# 2025-04-11  82270.703125  79553.265625  42343092224            4  54.972542
#
#                    MACD  MACD_signal  Bollinger_High  Bollinger_Low  \
# Date
# 2020-12-25          NaN          NaN             NaN            NaN
# 2020-12-26          NaN          NaN             NaN            NaN
# 2020-12-27          NaN          NaN             NaN            NaN
# 2020-12-28          NaN          NaN             NaN            NaN
# 2020-12-29          NaN          NaN             NaN            NaN
# ...                 ...          ...             ...            ...
# 2025-04-07 -1557.738511 -1204.760688    89029.606876   79109.436093
# 2025-04-08 -1935.892233 -1350.986997    89379.251873   77701.563752
# 2025-04-09 -1707.381420 -1422.265881    89306.680203   77614.811203
# 2025-04-10 -1744.044528 -1486.621611    89310.543070   77169.238180
# 2025-04-11 -1541.931782 -1497.683645    89240.128710   77083.474415
#
#               Close_lag1  ...  rolling_mean_10       mean_20  rolling_std_5  \
# Date                      ...
# 2020-12-25           NaN  ...              NaN           NaN            NaN
# 2020-12-26  24664.791016  ...              NaN           NaN            NaN
# 2020-12-27  26437.037109  ...              NaN           NaN            NaN
# 2020-12-28  26272.294922  ...              NaN           NaN            NaN
# 2020-12-29  27084.808594  ...              NaN           NaN    1050.892182
# ...                  ...  ...              ...           ...            ...
# 2025-04-07  78214.484375  ...     82303.715625  84069.521484    2644.466149
# 2025-04-08  79235.335938  ...     81671.152344  83540.407812    3335.431223
# 2025-04-09  76271.953125  ...     81695.095312  83460.745703    3023.738924
# 2025-04-10  82573.953125  ...     81402.817969  83239.890625    2297.274622
# 2025-04-11  79626.140625  ...     81112.971094  83161.801562    2569.243410
#
#                  std_10  is_month_end  is_friday  volume_change  \
# Date
# 2020-12-25          NaN             0          1            NaN
# 2020-12-26          NaN             0          0       0.148906
# 2020-12-27          NaN             0          0       0.375466
# 2020-12-28          NaN             0          0      -0.262082
# 2020-12-29          NaN             0          0      -0.077274
# ...                 ...           ...        ...            ...
# 2025-04-07  2081.164481             0          0       1.514473
# 2025-04-08  2814.163511             0          0      -0.470597
# 2025-04-09  2821.443716             0          0       0.743027
# 2025-04-10  2874.064261             0          0      -0.468993
# 2025-04-11  2583.492450             0          1      -0.053109
#
#             volume_rolling_mean_5  volume_rolling_std_5  target
# Date
# 2020-12-25                    NaN                   NaN       1
# 2020-12-26                    NaN                   NaN       0
# 2020-12-27                    NaN                   NaN       1
# 2020-12-28                    NaN                   NaN       1
# 2020-12-29           5.024073e+10          9.490635e+09       1
# ...                           ...                   ...     ...
# 2025-04-07           4.478957e+10          2.837128e+10       0
# 2025-04-08           4.708206e+10          2.803062e+10       1
# 2025-04-09           5.489326e+10          3.245319e+10       0
# 2025-04-10           6.096070e+10          2.495519e+10       1
# 2025-04-11           6.217035e+10          2.356874e+10       0
#
# [1561 rows x 30 columns]

# %%
print(f"Antes de dropna: {len(btc)} filas")
# Out:
# Antes de dropna: 1561 filas

# %%
# Elimina filas con NaNs generados por cálculos anteriores
btc.dropna(inplace=True)

# Filtra solo hasta el último día de febrero (ajusta si es otro año)
btc = btc[btc.index <= '2024-02-29']

# %%
print(f"Después de dropna: {len(btc)} filas")
# Out:
# Después de dropna: 1122 filas

# %%
btc
# Out:
#                    Close          Open        Volume  day_of_week      RSI_5  \
# Date
# 2021-01-28  33466.097656  30441.041016   76517157706            3  53.023512
# 2021-01-29  34316.386719  34318.671875  117894572511            4  59.132153
# 2021-01-30  34269.523438  34295.933594   65141828798            5  58.607115
# 2021-01-31  33114.359375  34270.878906   52754542671            6  46.017538
# 2021-02-01  33537.175781  33114.578125   61400400660            0  50.848319
# ...                  ...           ...           ...          ...        ...
# 2024-02-25  51733.238281  51565.214844   15413239245            6  60.533798
# 2024-02-26  54522.402344  51730.539062   34074411896            0  83.191229
# 2024-02-27  57085.371094  54519.363281   49756832031            1  89.870718
# 2024-02-28  62504.789062  57071.097656   83239156760            2  95.059687
# 2024-02-29  61198.382812  62499.183594   65496611844            3  82.348307
#
#                    MACD  MACD_signal  Bollinger_High  Bollinger_Low  \
# Date
# 2021-01-28   139.997778   871.332464    41063.463645   29800.734988
# 2021-01-29   198.026780   736.671327    40185.776363   30030.300005
# 2021-01-30   237.496002   636.836262    39310.845542   30306.728481
# 2021-01-31   173.562834   544.181576    38795.304267   30298.061553
# 2021-02-01   155.223765   466.390014    38688.479716   30201.938057
# ...                 ...          ...             ...            ...
# 2024-02-25  2011.481276  2152.020017    55417.722157   44239.575499
# 2024-02-26  2149.034185  2151.422851    55424.432572   45376.638131
# 2024-02-27  2436.766487  2208.491578    56053.675194   46024.110353
# 2024-02-28  3066.746602  2380.142583    58371.959498   45426.148315
# 2024-02-29  3421.157344  2588.345535    59861.339542   45341.886630
#
#               Close_lag1  ...  rolling_mean_10       mean_20  rolling_std_5  \
# Date                      ...
# 2021-01-28  30432.546875  ...     33444.529883  35432.099316    1106.375755
# 2021-01-29  33466.097656  ...     33213.161133  35108.038184    1453.002608
# 2021-01-30  34316.386719  ...     33033.133008  34808.787012    1607.642973
# 2021-01-31  34269.523438  ...     32789.793945  34546.682910    1588.628715
# 2021-02-01  33114.359375  ...     32842.935352  34445.208887     529.197638
# ...                  ...  ...              ...           ...            ...
# 2024-02-25  51571.101562  ...     51719.020703  49828.648828     442.157358
# 2024-02-26  51733.238281  ...     51955.240625  50400.535352    1475.205711
# 2024-02-27  54522.402344  ...     52497.478125  51038.892773    2632.275295
# 2024-02-28  57085.371094  ...     53535.702344  51899.053906    4532.094555
# 2024-02-29  62504.789062  ...     54477.626172  52601.613086    4499.387206
#
#                  std_10  is_month_end  is_friday  volume_change  \
# Date
# 2021-01-28  1996.829647             0          0       0.222773
# 2021-01-29  1698.466118             0          1       0.540760
# 2021-01-30  1437.376934             0          0      -0.447457
# 2021-01-31  1139.475131             1          0      -0.190159
# 2021-02-01  1162.818874             0          0       0.163888
# ...                 ...           ...        ...            ...
# 2024-02-25   455.422430             0          0       0.015761
# 2024-02-26   998.498567             0          0       1.210724
# 2024-02-27  1893.427556             0          0       0.460240
# 2024-02-28  3674.116896             0          0       0.672919
# 2024-02-29  4323.722500             1          0      -0.213151
#
#             volume_rolling_mean_5  volume_rolling_std_5  target
# Date
# 2021-01-28           6.157805e+10          9.950421e+09       1
# 2021-01-29           7.542819e+10          2.470409e+10       0
# 2021-01-30           7.647715e+10          2.398051e+10       0
# 2021-01-31           7.497697e+10          2.543926e+10       1
# 2021-02-01           7.474170e+10          2.558762e+10       1
# ...                           ...                   ...     ...
# 2024-02-25           2.121064e+10          5.973599e+09       1
# 2024-02-26           2.230054e+10          7.862909e+09       1
# 2024-02-27           2.716913e+10          1.477278e+10       1
# 2024-02-28           3.953154e+10          2.837107e+10       0
# 2024-02-29           4.959605e+10          2.642961e+10       1
#
# [1122 rows x 30 columns]

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1122 entries, 2021-01-28 to 2024-02-29
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Close                  1122 non-null   float64
#  1   Open                   1122 non-null   float64
#  2   Volume                 1122 non-null   int64
#  3   day_of_week            1122 non-null   int32
#  4   RSI_5                  1122 non-null   float64
#  5   MACD                   1122 non-null   float64
#  6   MACD_signal            1122 non-null   float64
#  7   Bollinger_High         1122 non-null   float64
#  8   Bollinger_Low          1122 non-null   float64
#  9   Close_lag1             1122 non-null   float64
#  10  Open_lag1              1122 non-null   float64
#  11  Close_lag2             1122 non-null   float64
#  12  RSI_5_lag1             1122 non-null   float64
#  13  MACD_lag1              1122 non-null   float64
#  14  daily_return           1122 non-null   float64
#  15  daily_return_lag1      1122 non-null   float64
#  16  daily_return_lag2      1122 non-null   float64
#  17  diff_pct               1122 non-null   float64
#  18  diff_pct_lag1          1122 non-null   float64
#  19  rolling_mean_5         1122 non-null   float64
#  20  rolling_mean_10        1122 non-null   float64
#  21  mean_20                1122 non-null   float64
#  22  rolling_std_5          1122 non-null   float64
#  23  std_10                 1122 non-null   float64
#  24  is_month_end           1122 non-null   int64
#  25  is_friday              1122 non-null   int64
#  26  volume_change          1122 non-null   float64
#  27  volume_rolling_mean_5  1122 non-null   float64
#  28  volume_rolling_std_5   1122 non-null   float64
#  29  target                 1122 non-null   int64
# dtypes: float64(25), int32(1), int64(4)
# memory usage: 267.4 KB

# %%
btc.to_csv('../../data/processed/btc_golder.csv')
