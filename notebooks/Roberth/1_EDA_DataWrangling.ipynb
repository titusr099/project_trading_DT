# %%
import yfinance as yf
import pandas as pd

# %%
# Descargar datos históricos para BTC
#Y,m,d
btc = yf.download('BTC-USD', start='2020-12-24', end='2025-04-09')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
btc
# Out:
# Price              Close          High           Low          Open  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2020-12-24  23735.949219  23768.337891  22777.597656  23240.203125
# 2020-12-25  24664.791016  24710.101562  23463.673828  23733.570312
# 2020-12-26  26437.037109  26718.070312  24522.689453  24677.015625
# 2020-12-27  26272.294922  28288.839844  25922.769531  26439.373047
# 2020-12-28  27084.808594  27389.111328  26207.640625  26280.822266
# ...                  ...           ...           ...           ...
# 2025-04-04  83843.804688  84696.148438  81670.750000  83100.250000
# 2025-04-05  83504.796875  84207.015625  82377.734375  83844.703125
# 2025-04-06  78214.484375  83704.718750  77097.742188  83504.507812
# 2025-04-07  79235.335938  81119.062500  74436.679688  78221.335938
# 2025-04-08  76271.953125  80823.890625  76198.023438  79218.476562
#
# Price            Volume
# Ticker          BTC-USD
# Date
# 2020-12-24  41080759713
# 2020-12-25  42068395846
# 2020-12-26  48332647295
# 2020-12-27  66479895605
# 2020-12-28  49056742893
# ...                 ...
# 2025-04-04  45157640207
# 2025-04-05  14380803631
# 2025-04-06  36294853736
# 2025-04-07  91262424987
# 2025-04-08  48314590749
#
# [1567 rows x 5 columns]

# %%
btc.to_csv('../../data/raw/BTC-USD.csv')

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1567 entries, 2020-12-24 to 2025-04-08
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Close, BTC-USD)   1567 non-null   float64
#  1   (High, BTC-USD)    1567 non-null   float64
#  2   (Low, BTC-USD)     1567 non-null   float64
#  3   (Open, BTC-USD)    1567 non-null   float64
#  4   (Volume, BTC-USD)  1567 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 73.5 KB

# %%
btc.columns = ['Close', 'High', 'Low', 'Open', 'Volume']

# %%
btc
# Out:
#                    Close          High           Low          Open  \
# Date
# 2020-12-24  23735.949219  23768.337891  22777.597656  23240.203125
# 2020-12-25  24664.791016  24710.101562  23463.673828  23733.570312
# 2020-12-26  26437.037109  26718.070312  24522.689453  24677.015625
# 2020-12-27  26272.294922  28288.839844  25922.769531  26439.373047
# 2020-12-28  27084.808594  27389.111328  26207.640625  26280.822266
# ...                  ...           ...           ...           ...
# 2025-04-04  83843.804688  84696.148438  81670.750000  83100.250000
# 2025-04-05  83504.796875  84207.015625  82377.734375  83844.703125
# 2025-04-06  78214.484375  83704.718750  77097.742188  83504.507812
# 2025-04-07  79235.335938  81119.062500  74436.679688  78221.335938
# 2025-04-08  76271.953125  80823.890625  76198.023438  79218.476562
#
#                  Volume
# Date
# 2020-12-24  41080759713
# 2020-12-25  42068395846
# 2020-12-26  48332647295
# 2020-12-27  66479895605
# 2020-12-28  49056742893
# ...                 ...
# 2025-04-04  45157640207
# 2025-04-05  14380803631
# 2025-04-06  36294853736
# 2025-04-07  91262424987
# 2025-04-08  48314590749
#
# [1567 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
btc.describe()
# Out:
#                Close           High            Low           Open  \
# count    1567.000000    1567.000000    1567.000000    1567.000000
# mean    45662.876058   46620.508942   44578.855694   45631.841983
# std     21937.643626   22378.964151   21445.925712   21932.476551
# min     15787.284180   16253.047852   15599.046875   15782.300781
# 25%     27778.728516   28270.688477   27229.441406   27756.757812
# 50%     41665.585938   42500.785156   40668.042969   41624.589844
# 75%     60374.962891   61581.541016   58882.244141   60356.068359
# max    106146.265625  109114.882812  105291.734375  106147.296875
#
#              Volume
# count  1.567000e+03
# mean   3.397887e+10
# std    2.132760e+10
# min    5.331173e+09
# 25%    2.003002e+10
# 50%    2.964060e+10
# 75%    4.113069e+10
# max    3.509679e+11

# %%
btc.isnull().sum()
# Out:
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
# Histograma de precio de cierre
plt.figure(figsize=(8,6))
sns.histplot(btc['Close'], bins=50, kde=True)
plt.title('Distribución del Precio de Cierre (BTC)')
plt.xlabel('Precio de Cierre (USD)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Serie temporal del precio de cierre
plt.figure(figsize=(14,7))
btc['Close'].plot()
plt.title('Precio de cierre diario de Bitcoin (BTC-USD)')
plt.ylabel('Precio en USD')
plt.xlabel('Fecha')
plt.grid(True)
plt.show()

# %%
# Matriz de correlación
plt.figure(figsize=(10,6))
sns.heatmap(btc[['Open', 'High', 'Low', 'Close', 'Volume']].corr(), annot=True, cmap='coolwarm')
plt.title('Matriz de correlación')
plt.show()

# %%
btc['daily_return'] = btc['Close'].pct_change()

# %%
# Calcula y visualiza retornos diarios
plt.figure(figsize=(12,6))
sns.histplot(btc['daily_return'].dropna(), bins=50, kde=True, color='purple')
plt.title('Distribución de los Retornos Diarios')
plt.xlabel('Retorno diario')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Serie temporal retornos diarios
plt.figure(figsize=(14,7))
btc['daily_return'].plot()
plt.title('Retornos diarios BTC-USD')
plt.ylabel('Retorno')
plt.xlabel('Fecha')
plt.grid(True)
plt.show()

# %%
# Promedio de retorno diario por día de la semana
btc['day_of_week'] = btc.index.dayofweek

weekly_return = btc.groupby('day_of_week')['daily_return'].mean()

plt.figure(figsize=(10,6))
weekly_return.plot(kind='bar', color='orange')
plt.title('Retorno promedio por día de la semana')
plt.ylabel('Retorno promedio')
plt.xlabel('Día de la semana (0=Lunes)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=btc['daily_return'])
plt.title('Boxplot de Retornos Diarios (detección rápida de outliers)')
plt.xlabel('Retorno diario')
plt.show()

# %%
Q1 = btc['daily_return'].quantile(0.25)
Q3 = btc['daily_return'].quantile(0.75)
IQR = Q3 - Q1

# Definir un rango más estricto, por ejemplo 2.5*IQR en vez de 1.5*IQR
limite_inferior = Q1 - 3.5 * IQR
limite_superior = Q3 + 3.5 * IQR

btc_filtrado = btc[(btc['daily_return'] >= limite_inferior) & (btc['daily_return'] <= limite_superior)]

# %%
btc_filtrado['daily_return'].describe()
plt.figure(figsize=(10,5))
sns.boxplot(x=btc_filtrado['daily_return'])
plt.title('Boxplot de Retornos Diarios (sin outliers)')
plt.xlabel('Retorno diario')
plt.show()

# %%
eliminados = len(btc) - len(btc_filtrado)
print(f"Se eliminaron {eliminados} datos extremos.")
# Out:
# Se eliminaron 9 datos extremos.

# %%
porcentaje = (eliminados / len(btc)) * 100
print(f"Se eliminó el {porcentaje:.2f}% de los datos.")
# Out:
# Se eliminó el 0.57% de los datos.

# %%
btc_filtrado.head()
# Out:
#                    Close          High           Low          Open  \
# Date
# 2020-12-25  24664.791016  24710.101562  23463.673828  23733.570312
# 2020-12-26  26437.037109  26718.070312  24522.689453  24677.015625
# 2020-12-27  26272.294922  28288.839844  25922.769531  26439.373047
# 2020-12-28  27084.808594  27389.111328  26207.640625  26280.822266
# 2020-12-29  27362.437500  27370.720703  25987.298828  27081.810547
#
#                  Volume  daily_return  day_of_week
# Date
# 2020-12-25  42068395846      0.039132            4
# 2020-12-26  48332647295      0.071853            5
# 2020-12-27  66479895605     -0.006231            6
# 2020-12-28  49056742893      0.030927            0
# 2020-12-29  45265946774      0.010250            1

# %%
btc_filtrado.to_csv('../../data/processed/btc_silver.csv')
